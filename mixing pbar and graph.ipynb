# %%
from glio.plot import LiveFigure
from glio.progress_bar import PBar
import random
fig = LiveFigure()
fig.add_plot("loss", (0,0))
fig.draw()
losses = []
for i in PBar(range(100)):
    losses.append(random.random())
    fig.update("loss", losses)
    fig.draw()
# Out:
# ▉▉▉▉                | 20/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 11
#       9 losses.append(random.random())
#      10 fig.update("loss", losses)
# ---> 11 fig.draw()
#
# File f:\Stuff\Programming\AI\glio_diff\glio\plot\live.py:311, in LiveFigure.draw(self, auto_redraw, force_redraw, figsize, layout, **kwargs)
#     305             ax.set_frame_on(False)
#     307     # self.draw() # this causes it to do stuff twice which may or may not fix not drawing bug, Dont Work
#     308
#     309 # self.fig.canvas.draw() # type:ignore
#     310 #display.clear_output(wait=True)
# --> 311 self.display.update(self.fig)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\display_functions.py:374, in DisplayHandle.update(self, obj, **kwargs)
#     364 def update(self, obj, **kwargs):
#     365     """Update existing displays with my id
# ...
